# %%
import pandas as pd
import pickle

# %%
df_doc = pd.read_csv('/mnt/c/users/cornelia/documents/AI/MasterThesis/IRDebias/data/bios/new_bios.tsv', sep="\t")
df_doc.groupby(['raw_title','gender']).count()
# Out:
#                                  Unnamed: 0  raw  bio  counter_bio
# raw_title                gender
# accountant               F               50   50   50           50
#                          M               50   50   50           50
# architect                F               50   50   50           50
#                          M               50   50   50           50
# assistant professor      F               50   50   50           50
#                          M               50   50   50           50
# associate professor      F               50   50   50           50
#                          M               50   50   50           50
# attorney                 F               50   50   50           50
#                          M               50   50   50           50
# dentist                  F               50   50   50           50
#                          M               50   50   50           50
# dietitian                F               50   50   50           50
#                          M               50   50   50           50
# interior designer        F               50   50   50           50
#                          M               50   50   50           50
# journalist               F               50   50   50           50
#                          M               50   50   50           50
# model                    F               50   50   50           50
#                          M               50   50   50           50
# nurse                    F               50   50   50           50
#                          M               50   50   50           50
# nutritionist             F               50   50   50           50
#                          M               50   50   50           50
# painter                  F               50   50   50           50
#                          M               50   50   50           50
# paralegal                F               50   50   50           50
#                          M               50   50   50           50
# personal trainer         F               50   50   50           50
#                          M               50   50   50           50
# photographer             F               50   50   50           50
#                          M               50   50   50           50
# physician                F               50   50   50           50
#                          M               50   50   50           50
# psychologist             F               50   50   50           50
#                          M               50   50   50           50
# psychotherapist          F               50   50   50           50
#                          M               50   50   50           50
# senior software engineer F               50   50   50           50
#                          M               50   50   50           50
# software engineer        F               50   50   50           50
#                          M               50   50   50           50
# surgeon                  F               50   50   50           50
#                          M               50   50   50           50
# teacher                  F               50   50   50           50
#                          M               50   50   50           50
# yoga instructor          F               50   50   50           50
#                          M               50   50   50           50

# %%
with open( '/mnt/c/Users/Cornelia/Documents/AI/MasterThesis/IRDebias/data/bios/train.pkl', 'rb') as file:
    dicts = pickle.load(file)
uk_jobs_train = pd.DataFrame(dicts)

# %%
uk_jobs_train
# Out:
#                          title  \
# 0                      dentist
# 1                 psychologist
# 2            software engineer
# 3                      dentist
# 4                      dentist
# ...                        ...
# 1454                   dentist
# 1455  senior software engineer
# 1456         software engineer
# 1457                   dentist
# 1458                   teacher
#
#                                             description
# 0      We’re looking for an to work with us at our w...
# 1      Pulse is currently recruiting for a patient a...
# 2     Sharp are looking for a  Software Engineer/App...
# 3     Associate Dentist Jobs in Bridgwater, Somerset...
# 4      We’re looking for an Associate Dentist to wor...
# ...                                                 ...
# 1454  Associate Dentist Jobs in Gloucestershire. IND...
# 1455   Senior Software Engineer | Fully Remote | £55...
# 1456    Job Title: Software Developer    Permanent  ...
# 1457    Associate Dentist – Stalybridge, Manchester ...
# 1458  Are you an inspiring, engaging teacher?Are you...
#
# [1459 rows x 2 columns]
